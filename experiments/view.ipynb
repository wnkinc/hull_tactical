# %%
import pandas as pd

df = pd.read_csv("results_allocation_lgb.csv")

# best variants overall
df.sort_values("score", ascending=False).head(20)

# compare within one allocation_fn
df[df["allocation_fn"] == "alloc_kelly"].sort_values("score", ascending=False)
# Out:
#     allocation_fn                                 variant     score
# 118   alloc_kelly  lgbRegressor + allFeats diff lateFolds  0.036503
# 107   alloc_kelly  lgbRegressor + engFeats diff lateFolds  0.032554
# 80    alloc_kelly            lgbRegressor + engFeats diff  0.025736
# 77    alloc_kelly                 lgbRegressor + allFeats  0.025583
# 74    alloc_kelly                           lgbClassifier  0.021611
# 79    alloc_kelly            lgbRegressor + allFeats diff  0.017716
# 76    alloc_kelly                lgbClassifier + allFeats  0.017153
# 73    alloc_kelly                            lgbRegressor  0.016557
# 78    alloc_kelly                 lgbRegressor + engFeats  0.016114
# 75    alloc_kelly                lgbClassifier + engFeats  0.015409
# 72    alloc_kelly                             last return -0.016253
